# %%
# !pip3 install selenium
# Out:
# Collecting selenium
#   Downloading https://files.pythonhosted.org/packages/80/d6/4294f0b4bce4de0abf13e17190289f9d0613b0a44e5dd6a7f5ca98459853/selenium-3.141.0-py2.py3-none-any.whl (904kB)
#      |████████████████████████████████| 911kB 4.8MB/s eta 0:00:01
# Collecting urllib3 (from selenium)
#   Downloading https://files.pythonhosted.org/packages/9f/f0/a391d1463ebb1b233795cabfc0ef38d3db4442339de68f847026199e69d7/urllib3-1.25.10-py2.py3-none-any.whl (127kB)
#      |████████████████████████████████| 133kB 11.9MB/s eta 0:00:01
# Installing collected packages: urllib3, selenium
# Successfully installed selenium-3.141.0 urllib3-1.25.10
# WARNING: You are using pip version 19.2.3, however version 20.2.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
from selenium import webdriver as wd
import time

# %%
driver = wd.Chrome('./chromedriver')

# %%
driver.get("https://www.metacritic.com/browse/movies/score/metascore/year/filtered?view=detailed&year_selected=2019")
time.sleep(2)
driver.find_element_by_css_selector('button#onetrust-accept-btn-handler').click()

# %%
titres = [element.text for element in driver.find_elements_by_css_selector('a.title h3')]
titres
# Out:
# ['Parasite',
#  'Portrait of a Lady on Fire',
#  'The Irishman',
#  'Marriage Story',
#  'Apocalypse Now: Final Cut',
#  'The Souvenir',
#  'Little Women',
#  'Uncut Gems',
#  '63 Up',
#  'For Sama',
#  'The Farewell',
#  "Long Day's Journey Into Night",
#  'Apollo 11',
#  'The Body Remembers When the World Broke Open',
#  'Pain and Glory',
#  'Genèse (Genesis)',
#  'Diane',
#  'An Elephant Sitting Still',
#  'Rolling Thunder Revue: A Bob Dylan Story by Martin Scorsese',
#  'One Cut of the Dead',
#  'Black Mother',
#  'The Wild Pear Tree',
#  'American Factory',
#  'Honeyland',
#  'Birds of Passage',
#  'Atlantics',
#  'Varda by Agnès',
#  'Ash Is Purest White',
#  'One Child Nation',
#  'Booksmart',
#  'Synonyms',
#  'Toy Story 4',
#  'In My Room',
#  'The Last Black Man in San Francisco',
#  'The Ground Beneath My Feet',
#  'Once Upon a Time ... in Hollywood',
#  'The Cave',
#  'The Lighthouse',
#  'Rosie',
#  'Roll Red Roll',
#  'Cunningham',
#  'Toni Morrison: The Pieces I Am',
#  'Wrestle',
#  'Relaxer',
#  'Transit',
#  'Maiden',
#  'Carmine Street Guitars',
#  'Knives Out',
#  'Angels Are Made of Light',
#  'Give Me Liberty',
#  'Invisible Life',
#  'I Do Not Care If We Go Down in History as Barbarians',
#  'Midnight Family',
#  'In Fabric',
#  'Us',
#  'Shadow',
#  'The Edge of Democracy',
#  'Chinese Portrait',
#  'Woman at War',
#  'Ford v Ferrari',
#  'The Chambermaid',
#  'Ray & Liz',
#  'The Proposal',
#  'Western Stars',
#  'Waves',
#  'Knock Down the House',
#  'I Lost My Body',
#  'Fiddler: A Miracle of Miracles',
#  'End of the Century',
#  'Making Waves: The Art of Cinematic Sound',
#  'Wild Rose',
#  'Ad Astra',
#  'Babylon',
#  'A Beautiful Day in the Neighborhood',
#  'Firecrackers',
#  'David Crosby: Remember My Name',
#  'Aquarela',
#  'Light From Light',
#  'Too Late to Die Young',
#  'All Is Well',
#  'Mickey and the Bear',
#  'Working Woman',
#  'Funan',
#  'Gloria Bell',
#  'Socrates',
#  'Hotel by the River',
#  'Midnight Traveler',
#  'Chained for Life',
#  'Celebration',
#  'Hustlers',
#  'Styx',
#  '3 Faces',
#  'Holiday',
#  'Love, Antosha',
#  'Monos',
#  'High Flying Bird',
#  'Diego Maradona',
#  'Avengers: Endgame',
#  'A Hidden Life',
#  'Non-Fiction']

# %%
notes_meta = [element.text for element in driver.find_elements_by_css_selector('div.clamp-score-wrap a div')]
notes_meta
# Out:
# ['96',
#  '95',
#  '94',
#  '94',
#  '92',
#  '91',
#  '91',
#  '91',
#  '89',
#  '89',
#  '89',
#  '88',
#  '88',
#  '87',
#  '87',
#  '87',
#  '86',
#  '86',
#  '86',
#  '86',
#  '86',
#  '86',
#  '86',
#  '86',
#  '85',
#  '85',
#  '85',
#  '85',
#  '85',
#  '84',
#  '84',
#  '84',
#  '84',
#  '83',
#  '83',
#  '83',
#  '83',
#  '83',
#  '83',
#  '83',
#  '83',
#  '82',
#  '82',
#  '82',
#  '82',
#  '82',
#  '82',
#  '82',
#  '82',
#  '82',
#  '81',
#  '81',
#  '81',
#  '81',
#  '81',
#  '81',
#  '81',
#  '81',
#  '81',
#  '81',
#  '81',
#  '81',
#  '80',
#  '80',
#  '80',
#  '80',
#  '80',
#  '80',
#  '80',
#  '80',
#  '80',
#  '80',
#  '80',
#  '80',
#  '80',
#  '80',
#  '80',
#  '80',
#  '80',
#  '80',
#  '79',
#  '79',
#  '79',
#  '79',
#  '79',
#  '79',
#  '79',
#  '79',
#  '79',
#  '79',
#  '78',
#  '78',
#  '78',
#  '78',
#  '78',
#  '78',
#  '78',
#  '78',
#  '78',
#  '78']

# %%
btn = driver.find_elements_by_css_selector('label.clamp-list-expand-label')
for b in btn:
    b.click()
time.sleep(2)
notes_user = [element.text for element in driver.find_elements_by_css_selector('div.clamp-userscore a div')]
notes_user
# Out:
# ---------------------------------------------------------------------------
# ElementClickInterceptedException          Traceback (most recent call last)
# <ipython-input-29-a7d7beda6a2f> in <module>
#       1 btn = driver.find_elements_by_css_selector('label.clamp-list-expand-label')
#       2 for b in btn:
# ----> 3     b.click()
#       4 time.sleep(2)
#       5 notes_user = [element.text for element in driver.find_elements_by_css_selector('div.clamp-userscore a div')]
#
# ~/Desktop/nouveau_projet/monenv/lib/python3.7/site-packages/selenium/webdriver/remote/webelement.py in click(self)
#      78     def click(self):
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# ~/Desktop/nouveau_projet/monenv/lib/python3.7/site-packages/selenium/webdriver/remote/webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# ~/Desktop/nouveau_projet/monenv/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~/Desktop/nouveau_projet/monenv/lib/python3.7/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# ElementClickInterceptedException: Message: element click intercepted: Element <label for="551009" class="clamp-list-expand-label"></label> is not clickable at point (794, 622). Other element would receive the click: <html xmlns:og="http://opengraphprotocol.org/schema/" xmlns:fb="http://ogp.me/ns/fb#" data-triggered="true">...</html>
#   (Session info: chrome=85.0.4183.102)

# %%
dates = [element.text for element in driver.find_elements_by_css_selector('div.clamp-details span:first-child')]
dates

# %%
driver.close()
import pandas as pd

# %%
data = pd.DataFrame({"date": dates, "title": titres, "metascore": notes_meta, "userscore": notes_user})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-23f7cb120c08> in <module>
# ----> 1 data = pd.DataFrame({"date": dates, "title": titres, "metascore": notes_meta, "userscore": notes_user})
#
# NameError: name 'dates' is not defined

# %%
data
# Out:
#                   date                       title metascore
# 0     October 11, 2019                    Parasite        96
# 1     December 6, 2019  Portrait of a Lady on Fire        95
# 2     November 1, 2019                The Irishman        94
# 3     November 6, 2019              Marriage Story        94
# 4      August 15, 2019   Apocalypse Now: Final Cut        92
# ..                 ...                         ...       ...
# 95    February 8, 2019            High Flying Bird        78
# 96  September 20, 2019              Diego Maradona        78
# 97      April 26, 2019           Avengers: Endgame        78
# 98   December 13, 2019               A Hidden Life        78
# 99         May 3, 2019                 Non-Fiction        78
#
# [100 rows x 3 columns]
