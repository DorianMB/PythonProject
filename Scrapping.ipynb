# %%
# !pip3 install selenium
# Out:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/site-packages/pip/_vendor/pkg_resources/__init__.py", line 583, in _build_master
#     ws.require(__requires__)
#   File "/usr/local/lib/python3.8/site-packages/pip/_vendor/pkg_resources/__init__.py", line 900, in require
#     needed = self.resolve(parse_requirements(requirements))
#   File "/usr/local/lib/python3.8/site-packages/pip/_vendor/pkg_resources/__init__.py", line 791, in resolve
#     raise VersionConflict(dist, req).with_context(dependent_req)
# pip._vendor.pkg_resources.VersionConflict: (pip 20.2.3 (/usr/local/lib/python3.8/site-packages), Requirement.parse('pip==20.1.1'))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/opt/python@3.8/bin/pip3", line 33, in <module>
#     sys.exit(load_entry_point('pip==20.1.1', 'console_scripts', 'pip3')())
#   File "/usr/local/opt/python@3.8/bin/pip3", line 25, in importlib_load_entry_point
#     return next(matches).load()
#   File "/usr/local/Cellar/python@3.8/3.8.5/Frameworks/Python.framework/Versions/3.8/lib/python3.8/importlib/metadata.py", line 77, in load
#     module = import_module(match.group('module'))
#   File "/usr/local/Cellar/python@3.8/3.8.5/Frameworks/Python.framework/Versions/3.8/lib/python3.8/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1014, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 991, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 975, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 671, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 783, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/usr/local/lib/python3.8/site-packages/pip/_internal/cli/main.py", line 10, in <module>
#     from pip._internal.cli.autocompletion import autocomplete
#   File "/usr/local/lib/python3.8/site-packages/pip/_internal/cli/autocompletion.py", line 9, in <module>
#     from pip._internal.cli.main_parser import create_main_parser
#   File "/usr/local/lib/python3.8/site-packages/pip/_internal/cli/main_parser.py", line 7, in <module>
#     from pip._internal.cli import cmdoptions
#   File "/usr/local/lib/python3.8/site-packages/pip/_internal/cli/cmdoptions.py", line 23, in <module>
#     from pip._internal.cli.progress_bars import BAR_TYPES
#   File "/usr/local/lib/python3.8/site-packages/pip/_internal/cli/progress_bars.py", line 12, in <module>
#     from pip._internal.utils.logging import get_indentation
#   File "/usr/local/lib/python3.8/site-packages/pip/_internal/utils/logging.py", line 18, in <module>
#     from pip._internal.utils.misc import ensure_dir
#   File "/usr/local/lib/python3.8/site-packages/pip/_internal/utils/misc.py", line 21, in <module>
#     from pip._vendor import pkg_resources
#   File "/usr/local/lib/python3.8/site-packages/pip/_vendor/pkg_resources/__init__.py", line 3252, in <module>
#     def _initialize_master_working_set():
#   File "/usr/local/lib/python3.8/site-packages/pip/_vendor/pkg_resources/__init__.py", line 3235, in _call_aside
#     f(*args, **kwargs)
#   File "/usr/local/lib/python3.8/site-packages/pip/_vendor/pkg_resources/__init__.py", line 3264, in _initialize_master_working_set
#     working_set = WorkingSet._build_master()
#   File "/usr/local/lib/python3.8/site-packages/pip/_vendor/pkg_resources/__init__.py", line 585, in _build_master
#     return cls._build_from_requirements(__requires__)
#   File "/usr/local/lib/python3.8/site-packages/pip/_vendor/pkg_resources/__init__.py", line 598, in _build_from_requirements
#     dists = ws.resolve(reqs, Environment())
#   File "/usr/local/lib/python3.8/site-packages/pip/_vendor/pkg_resources/__init__.py", line 786, in resolve
#     raise DistributionNotFound(req, requirers)
# pip._vendor.pkg_resources.DistributionNotFound: The 'pip==20.1.1' distribution was not found and is required by the application

# %%
from selenium import webdriver as wd
import time

# %%
driver = wd.Chrome('./chromedriver')

# %%
driver.get("https://www.metacritic.com/browse/movies/score/metascore/year/filtered?view=detailed&year_selected=2019")
time.sleep(2)
driver.find_element_by_css_selector('button#onetrust-accept-btn-handler').click()

# %%
titres = [element.text for element in driver.find_elements_by_css_selector('a.title h3')]
titres
# Out:
# ['Parasite',
#  'Portrait of a Lady on Fire',
#  'The Irishman',
#  'Marriage Story',
#  'Apocalypse Now: Final Cut',
#  'The Souvenir',
#  'Little Women',
#  'Uncut Gems',
#  '63 Up',
#  'For Sama',
#  'The Farewell',
#  "Long Day's Journey Into Night",
#  'Apollo 11',
#  'The Body Remembers When the World Broke Open',
#  'Pain and Glory',
#  'Genèse (Genesis)',
#  'Diane',
#  'An Elephant Sitting Still',
#  'Rolling Thunder Revue: A Bob Dylan Story by Martin Scorsese',
#  'One Cut of the Dead',
#  'Black Mother',
#  'The Wild Pear Tree',
#  'American Factory',
#  'Honeyland',
#  'Birds of Passage',
#  'Atlantics',
#  'Varda by Agnès',
#  'Ash Is Purest White',
#  'One Child Nation',
#  'Booksmart',
#  'Synonyms',
#  'Toy Story 4',
#  'In My Room',
#  'The Last Black Man in San Francisco',
#  'The Ground Beneath My Feet',
#  'Once Upon a Time ... in Hollywood',
#  'The Cave',
#  'The Lighthouse',
#  'Rosie',
#  'Roll Red Roll',
#  'Cunningham',
#  'Toni Morrison: The Pieces I Am',
#  'Wrestle',
#  'Relaxer',
#  'Transit',
#  'Maiden',
#  'Carmine Street Guitars',
#  'Knives Out',
#  'Angels Are Made of Light',
#  'Give Me Liberty',
#  'Invisible Life',
#  'I Do Not Care If We Go Down in History as Barbarians',
#  'Midnight Family',
#  'In Fabric',
#  'Us',
#  'Shadow',
#  'The Edge of Democracy',
#  'Chinese Portrait',
#  'Woman at War',
#  'Ford v Ferrari',
#  'The Chambermaid',
#  'Ray & Liz',
#  'The Proposal',
#  'Western Stars',
#  'Waves',
#  'Knock Down the House',
#  'I Lost My Body',
#  'Fiddler: A Miracle of Miracles',
#  'End of the Century',
#  'Making Waves: The Art of Cinematic Sound',
#  'Wild Rose',
#  'Ad Astra',
#  'Babylon',
#  'A Beautiful Day in the Neighborhood',
#  'Firecrackers',
#  'David Crosby: Remember My Name',
#  'Aquarela',
#  'Light From Light',
#  'Too Late to Die Young',
#  'All Is Well',
#  'Mickey and the Bear',
#  'Working Woman',
#  'Funan',
#  'Gloria Bell',
#  'Socrates',
#  'Hotel by the River',
#  'Midnight Traveler',
#  'Chained for Life',
#  'Celebration',
#  'Hustlers',
#  'Styx',
#  '3 Faces',
#  'Holiday',
#  'Love, Antosha',
#  'Monos',
#  'High Flying Bird',
#  'Diego Maradona',
#  'Avengers: Endgame',
#  'A Hidden Life',
#  'Non-Fiction']

# %%
notes_meta = [element.text for element in driver.find_elements_by_css_selector('div.clamp-score-wrap a div')]
notes_meta
# Out:
# ['96',
#  '95',
#  '94',
#  '94',
#  '92',
#  '91',
#  '91',
#  '91',
#  '89',
#  '89',
#  '89',
#  '88',
#  '88',
#  '87',
#  '87',
#  '87',
#  '86',
#  '86',
#  '86',
#  '86',
#  '86',
#  '86',
#  '86',
#  '86',
#  '85',
#  '85',
#  '85',
#  '85',
#  '85',
#  '84',
#  '84',
#  '84',
#  '84',
#  '83',
#  '83',
#  '83',
#  '83',
#  '83',
#  '83',
#  '83',
#  '83',
#  '82',
#  '82',
#  '82',
#  '82',
#  '82',
#  '82',
#  '82',
#  '82',
#  '82',
#  '81',
#  '81',
#  '81',
#  '81',
#  '81',
#  '81',
#  '81',
#  '81',
#  '81',
#  '81',
#  '81',
#  '81',
#  '80',
#  '80',
#  '80',
#  '80',
#  '80',
#  '80',
#  '80',
#  '80',
#  '80',
#  '80',
#  '80',
#  '80',
#  '80',
#  '80',
#  '80',
#  '80',
#  '80',
#  '80',
#  '79',
#  '79',
#  '79',
#  '79',
#  '79',
#  '79',
#  '79',
#  '79',
#  '79',
#  '79',
#  '78',
#  '78',
#  '78',
#  '78',
#  '78',
#  '78',
#  '78',
#  '78',
#  '78',
#  '78']

# %%
btn = driver.find_elements_by_css_selector('label.clamp-list-expand-label')
for b in btn:
    b.click()
notes_user = [element.text for element in driver.find_elements_by_css_selector('div.clamp-userscore a div')]
notes_user
# Out:
# ['8.9',
#  '8.7',
#  '8.1',
#  '8.2',
#  '8.6',
#  '6.8',
#  '7.5',
#  '7.1',
#  'tbd',
#  '7.5',
#  '8.3',
#  '6.8',
#  '8.2',
#  'tbd',
#  '7.9',
#  'tbd',
#  '7.2',
#  '8.8',
#  '8.1',
#  '8.1',
#  '3.9',
#  '7.6',
#  '7.5',
#  '8.7',
#  '7.6',
#  '6.3',
#  '7.0',
#  '6.7',
#  '8.1',
#  '4.7',
#  '5.7',
#  '8.0',
#  'tbd',
#  '7.2',
#  'tbd',
#  '7.5',
#  '7.0',
#  '8.0',
#  '5.4',
#  '8.6',
#  'tbd',
#  '6.8',
#  'tbd',
#  '6.5',
#  '6.4',
#  '7.7',
#  'tbd',
#  '7.6',
#  'tbd',
#  '7.9',
#  '8.6',
#  'tbd',
#  'tbd',
#  '6.1',
#  '6.4',
#  '7.2',
#  '5.3',
#  'tbd',
#  '5.8',
#  '8.3',
#  '6.8',
#  '7.3',
#  'tbd',
#  '6.3',
#  '7.3',
#  '1.1',
#  '8.0',
#  'tbd',
#  '5.9',
#  'tbd',
#  '8.9',
#  '6.1',
#  'tbd',
#  '7.1',
#  '5.5',
#  '6.0',
#  '4.5',
#  'tbd',
#  '7.8',
#  'tbd',
#  '5.8',
#  '5.2',
#  '6.5',
#  '6.7',
#  'tbd',
#  '7.7',
#  '7.0',
#  'tbd',
#  'tbd',
#  '6.1',
#  '7.0',
#  '6.1',
#  '6.3',
#  '6.0',
#  '7.4',
#  '6.0',
#  '8.3',
#  '7.8',
#  '7.6',
#  '6.7']

# %%
dates = [element.text for element in driver.find_elements_by_css_selector('div.clamp-details span:first-child')]
dates
# Out:
# ['October 11, 2019',
#  'December 6, 2019',
#  'November 1, 2019',
#  'November 6, 2019',
#  'August 15, 2019',
#  'May 17, 2019',
#  'December 25, 2019',
#  'December 13, 2019',
#  'November 27, 2019',
#  'July 26, 2019',
#  'July 12, 2019',
#  'April 12, 2019',
#  'March 1, 2019',
#  'November 22, 2019',
#  'October 4, 2019',
#  'August 23, 2019',
#  'March 29, 2019',
#  'March 8, 2019',
#  'June 12, 2019',
#  'September 13, 2019',
#  'March 8, 2019',
#  'January 30, 2019',
#  'August 21, 2019',
#  'July 26, 2019',
#  'February 13, 2019',
#  'November 15, 2019',
#  'November 22, 2019',
#  'March 15, 2019',
#  'August 9, 2019',
#  'May 24, 2019',
#  'October 25, 2019',
#  'June 21, 2019',
#  'October 11, 2019',
#  'June 7, 2019',
#  'July 26, 2019',
#  'July 26, 2019',
#  'October 18, 2019',
#  'October 18, 2019',
#  'July 19, 2019',
#  'March 22, 2019',
#  'December 13, 2019',
#  'June 21, 2019',
#  'February 22, 2019',
#  'March 22, 2019',
#  'March 1, 2019',
#  'June 28, 2019',
#  'April 24, 2019',
#  'November 27, 2019',
#  'July 24, 2019',
#  'August 23, 2019',
#  'December 20, 2019',
#  'July 19, 2019',
#  'December 6, 2019',
#  'December 6, 2019',
#  'March 22, 2019',
#  'May 3, 2019',
#  'June 19, 2019',
#  'December 13, 2019',
#  'March 1, 2019',
#  'November 15, 2019',
#  'June 26, 2019',
#  'July 10, 2019',
#  'May 24, 2019',
#  'October 25, 2019',
#  'November 15, 2019',
#  'May 1, 2019',
#  'November 15, 2019',
#  'August 23, 2019',
#  'August 16, 2019',
#  'October 25, 2019',
#  'June 21, 2019',
#  'September 20, 2019',
#  'March 8, 2019',
#  'November 22, 2019',
#  'July 12, 2019',
#  'July 19, 2019',
#  'August 16, 2019',
#  'November 1, 2019',
#  'May 31, 2019',
#  'June 6, 2019',
#  'November 13, 2019',
#  'March 29, 2019',
#  'June 7, 2019',
#  'March 8, 2019',
#  'August 9, 2019',
#  'February 15, 2019',
#  'September 18, 2019',
#  'September 13, 2019',
#  'October 2, 2019',
#  'September 13, 2019',
#  'February 27, 2019',
#  'March 8, 2019',
#  'February 8, 2019',
#  'August 2, 2019',
#  'September 13, 2019',
#  'February 8, 2019',
#  'September 20, 2019',
#  'April 26, 2019',
#  'December 13, 2019',
#  'May 3, 2019']

# %%
driver.close()
import pandas as pd

# %%
data = pd.DataFrame({"date": dates, "title": titres, "metascore": notes_meta, "userscore": notes_user})
data["userscore"] = pd.to_numeric(data["userscore"], downcast="float", errors='coerce')

# %%
data[pd.isna(data["userscore"])]
# Out:
#                   date                                              title  \
# 8    November 27, 2019                                              63 Up
# 13   November 22, 2019       The Body Remembers When the World Broke Open
# 15     August 23, 2019                                   Genèse (Genesis)
# 32    October 11, 2019                                         In My Room
# 34       July 26, 2019                         The Ground Beneath My Feet
# 40   December 13, 2019                                         Cunningham
# 42   February 22, 2019                                            Wrestle
# 46      April 24, 2019                             Carmine Street Guitars
# 48       July 24, 2019                           Angels Are Made of Light
# 51       July 19, 2019  I Do Not Care If We Go Down in History as Barb...
# 52    December 6, 2019                                    Midnight Family
# 57   December 13, 2019                                   Chinese Portrait
# 62        May 24, 2019                                       The Proposal
# 67     August 23, 2019                     Fiddler: A Miracle of Miracles
# 69    October 25, 2019           Making Waves: The Art of Cinematic Sound
# 72       March 8, 2019                                            Babylon
# 77    November 1, 2019                                   Light From Light
# 79        June 6, 2019                                        All Is Well
# 84      August 9, 2019                                           Socrates
# 87  September 13, 2019                                   Chained for Life
# 88     October 2, 2019                                        Celebration
#
#    metascore  userscore
# 8         89        NaN
# 13        87        NaN
# 15        87        NaN
# 32        84        NaN
# 34        83        NaN
# 40        83        NaN
# 42        82        NaN
# 46        82        NaN
# 48        82        NaN
# 51        81        NaN
# 52        81        NaN
# 57        81        NaN
# 62        80        NaN
# 67        80        NaN
# 69        80        NaN
# 72        80        NaN
# 77        80        NaN
# 79        80        NaN
# 84        79        NaN
# 87        79        NaN
# 88        79        NaN

# %%
data.head
# Out:
# <bound method NDFrame.head of                   date                       title metascore  userscore
# 0     October 11, 2019                    Parasite        96        8.9
# 1     December 6, 2019  Portrait of a Lady on Fire        95        8.7
# 2     November 1, 2019                The Irishman        94        8.1
# 3     November 6, 2019              Marriage Story        94        8.2
# 4      August 15, 2019   Apocalypse Now: Final Cut        92        8.6
# ..                 ...                         ...       ...        ...
# 95    February 8, 2019            High Flying Bird        78        6.0
# 96  September 20, 2019              Diego Maradona        78        8.3
# 97      April 26, 2019           Avengers: Endgame        78        7.8
# 98   December 13, 2019               A Hidden Life        78        7.6
# 99         May 3, 2019                 Non-Fiction        78        6.7
#
# [100 rows x 4 columns]>

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
tochart = data[pd.notna(data["userscore"])].sample(5)
tochart['userscore'] = tochart['userscore'].astype(str).str.replace('.', '').str[0:2]
tochart
# Out:
#                  date                title metascore userscore
# 12      March 1, 2019            Apollo 11        88        81
# 76    August 16, 2019             Aquarela        80        45
# 80  November 13, 2019  Mickey and the Bear        79        58
# 64  November 15, 2019                Waves        80        73
# 16     March 29, 2019                Diane        86        71

# %%
labels = tochart['title']
metascore = tochart['metascore']
userscore = tochart['userscore']

x = np.arange(len(labels))
width = 0.35

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, metascore, width, label='Metascore')
rects2 = ax.bar(x + width/2, userscore, width, label='Public score')

ax.set_ylabel('Score')
ax.set_title('Scores by Meta and public')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

fig.tight_layout()

plt.show()
